# %% [markdown]
# ## Independent Project: Converting Election Data from NBC into a CSV File
#
# While looking for project ideas on Kaggle, [this dataset](https://www.kaggle.com/imoore/2020-us-general-election-turnout-rates/activity) caught my eye. My first instinct was to investigate if there was a correlation between the turnout in a state, and the share of votes that Joe Biden or Donald Trump recieved there.
#
# However, a Google search for '2020 Election Results CSV' didn't yield any results. That's frustrating, given that several news outlets have published this data. Why hasn't someone turned it into a csv? Wait - why don't I convert it into a CSV from a news outlet's site?
#
# ### Part 1: Web Scraping using Beautiful Soup
# I decided to use the vote count published [here](https://www.nbcnews.com/politics/2020-elections/president-results) on the NBC News Website.
#
# I loaded the table data into a using the 'tbody' tag, which stands for 'table body'. I then used the 'div' tag, which represents a new row in the table, to separate data from each State/Territory into its own item.
#
# I then loaded each element of the voting results into its own list:
# - State Name
# - Electoral Votes
# - Percent of Vote Counted
# - Biden's Votes
# - Trump's Votes

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
url = "https://www.nbcnews.com/politics/2020-elections/president-results"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, 'html.parser')

# %%
all_data = soup.find('tbody')
state_data = all_data.find_all('div')
print(len(state_data))
# Out:
# 56

# %%
print(state_data[1])
# I printed the HTML block to use as a reference for parsing each state's results, so that 
# I wouldn't have to refer back to the original webpage during this process.
# Out:
# <div data-all='{"totalElectoralVotes":3,"percentOfVotesInFormatted":"99%","href":"/politics/2020-elections/alaska-president-results?icid=election_usmap","candidates":[{"lastName":"Trump","firstName":"Donald","totalVotesReceived":189951,"percentageOfVotesReceivedFormatted":"52.8%","totalVotesReceivedFormatted":"189,951","percentageOfVotesReceived":52.8,"isWinner":true,"colorHex":"#DE3535","colorHexValue":"#DE3535"},{"lastName":"Biden","firstName":"Joe","totalVotesReceived":153778,"percentageOfVotesReceivedFormatted":"42.8%","totalVotesReceivedFormatted":"153,778","percentageOfVotesReceived":42.8,"isWinner":false,"colorHex":"#0471E6","colorHexValue":"#0471E6"}],"callStatus":"","raceHasStarted":true,"pollsClose":"1AM","name":"Alaska","isPollsClosed":true}' data-us-state="Alaska"><tr><th scope="row">Alaska</th><td>3</td><td>99%</td><td>Biden 42.8% 153,778 votes</td><td>Trump 52.8% 189,951 votes</td><td><a class="" href="/politics/2020-elections/alaska-president-results?icid=election_usmap">Go to page Alaska results page</a></td></tr></div>

# %%
states = [] 
electoral_votes = []
pct_counted = []
biden = [] 
trump = []
url = [] 
for item in state_data: 
    state_name = item.tr.find('th', scope='row').text
    states.append(state_name)
    
    e_votes = item.tr.find_all('td')[0].text
    electoral_votes.append(e_votes)
    
    percent_in = item.tr.find_all('td')[1].text
    pct_counted.append(percent_in)
    
    biden_votes = item.tr.find_all('td')[2].text
    biden.append(biden_votes)
    
    #trump_votes = item.tr.find_all('td')[3].text
    #trump.append(trump_votes)
    for a in item.find_all('a', href=True):
        state_url = a['href']
    url.append(state_url)

# %% [markdown]
# #### 1.1: Getting Creative
#
# This method worked for all lists except for Trump's results. This likely means that there are inconsistencies in the way the data is stored in each row in the table.
#
# I verified that the parsing worked for most elements by printing the first result in each list above. I suspected the inconsistency is coming from the territories, and not the US states.
#
# To get a list of Trump's results, I used a ReGex pattern iterating over the table results. I can see that the  length of this list is five less than the length of the other lists.

# %%
print("length:",len(states),"first result:",states[0])
print("length:",len(electoral_votes),"first result:", electoral_votes[0])
print("length:",len(pct_counted),"first result:",pct_counted[0])
print("length:",len(biden),"first result:",biden[0])
print("length:",len(url),"first result:",url[0])
# Out:
# length: 56 first result: Alabama
# length: 56 first result: 9
# length: 56 first result: 100%
# length: 56 first result: Biden 36.6% 849,648 votes
# length: 56 first result: /politics/2020-elections/alabama-president-results?icid=election_usmap

# %%
import re
trump = all_data.find_all(string=re.compile(r"Trump"))
print(len(trump))
# Out:
# 51

# %% [markdown]
# ### Part Two: Creating the DataFrame
#
# To determine which entries had incomplete information, I read the information into a dataframe and printed the results. I can see that American Samoa, Guam, the Mariana Islands, the Virgin Islands, and Puerto Rico do not have complete information. Interestingly, these territories are not actually present in the table on the original webpage.
#
# I removed them from my analysis, then added Trump's results as a column in the dataframe.

# %%
import pandas as pd
import numpy as np
results_2020 = pd.DataFrame({'State':states,'Electoral Votes':electoral_votes,
                             '% Vote Counted':pct_counted, 'Biden Results':biden,'URL':url})
print(results_2020)
# Out:
#                                            State Electoral Votes  \
# 0                                        Alabama               9
# 1                                         Alaska               3
# 2                                        Arizona              11
# 3                                       Colorado               9
# 4                                        Florida              29
# 5                                        Georgia              16
# 6                                        Indiana              11
# 7                                         Kansas               6
# 8                                          Maine               4
# 9                                  Massachusetts              11
# 10                                     Minnesota              10
# 11                                    New Jersey              14
# 12                                North Carolina              15
# 13                                  North Dakota               3
# 14                                      Oklahoma               7
# 15                                  Pennsylvania              20
# 16                                  South Dakota               3
# 17                                         Texas              38
# 18                                       Wyoming               3
# 19                                   Connecticut               7
# 20                                      Missouri              10
# 21                                 West Virginia               5
# 22                                      Illinois              20
# 23                                    New Mexico               5
# 24                                      Arkansas               6
# 25                                    California              55
# 26                                      Delaware               3
# 27                          District of Columbia               3
# 28                                        Hawaii               4
# 29                                          Iowa               6
# 30                                      Kentucky               8
# 31                                      Maryland              10
# 32                                      Michigan              16
# 33                                   Mississippi               6
# 34                                       Montana               3
# 35                                 New Hampshire               4
# 36                                      New York              29
# 37                                          Ohio              18
# 38                                        Oregon               7
# 39                                     Tennessee              11
# 40                                          Utah               6
# 41                                      Virginia              13
# 42                                    Washington              12
# 43                                     Wisconsin              10
# 44                                American Samoa
# 45                                          Guam
# 46  Commonwealth of the Northern Mariana Islands
# 47                                      Nebraska               5
# 48                                South Carolina               9
# 49                                   Puerto Rico
# 50                  United States Virgin Islands
# 51                                         Idaho               4
# 52                                        Nevada               6
# 53                                       Vermont               3
# 54                                     Louisiana               8
# 55                                  Rhode Island               4
#
#    % Vote Counted                                      Biden Results  \
# 0            100%                          Biden 36.6% 849,648 votes
# 1             99%                          Biden 42.8% 153,778 votes
# 2            100%                        Biden 49.4% 1,672,143 votes
# 3             99%                        Biden 55.4% 1,804,352 votes
# 4            100%                        Biden 47.9% 5,297,045 votes
# 5            100%                        Biden 49.5% 2,473,633 votes
# 6            100%                          Biden 41% 1,242,495 votes
# 7            100%                          Biden 41.5% 570,323 votes
# 8            100%                          Biden 53.1% 435,072 votes
# 9            100%                        Biden 65.6% 2,382,202 votes
# 10           100%                        Biden 52.4% 1,717,077 votes
# 11           100%                        Biden 57.1% 2,608,335 votes
# 12           100%                        Biden 48.6% 2,684,292 votes
# 13           100%                          Biden 31.8% 114,902 votes
# 14           100%                          Biden 32.3% 503,890 votes
# 15           100%                          Biden 50% 3,459,923 votes
# 16           100%                          Biden 35.6% 150,471 votes
# 17           100%                        Biden 46.5% 5,259,126 votes
# 18           100%                           Biden 26.6% 73,491 votes
# 19           100%                        Biden 59.2% 1,080,680 votes
# 20           100%                        Biden 41.4% 1,253,014 votes
# 21           100%                          Biden 29.7% 235,984 votes
# 22            99%                        Biden 57.5% 3,471,915 votes
# 23           100%                          Biden 54.3% 501,614 votes
# 24           100%                          Biden 34.8% 423,932 votes
# 25           100%                       Biden 63.5% 11,109,764 votes
# 26           100%                          Biden 58.8% 296,268 votes
# 27           100%                          Biden 92.1% 317,323 votes
# 28           100%                          Biden 63.7% 366,130 votes
# 29           100%                          Biden 44.9% 759,061 votes
# 30           100%                          Biden 36.2% 772,474 votes
# 31           100%                        Biden 65.4% 1,985,023 votes
# 32           100%                        Biden 50.6% 2,804,040 votes
# 33           100%                            Biden 41% 539,398 votes
# 34           100%                          Biden 40.4% 244,786 votes
# 35           100%                          Biden 52.8% 424,921 votes
# 36           100%                        Biden 60.9% 5,244,006 votes
# 37           100%                        Biden 45.2% 2,679,165 votes
# 38           100%                        Biden 56.5% 1,340,383 votes
# 39           100%                        Biden 37.4% 1,143,913 votes
# 40           100%                          Biden 37.6% 560,282 votes
# 41           100%                        Biden 54.1% 2,413,568 votes
# 42           100%                          Biden 58% 2,369,612 votes
# 43           100%                        Biden 49.5% 1,630,673 votes
# 44                            Go to page American Samoa results page
# 45                                      Go to page Guam results page
# 46                 Go to page Commonwealth of the Northern Marian...
# 47           100%                          Biden 39.2% 374,583 votes
# 48           100%                        Biden 43.4% 1,091,541 votes
# 49                               Go to page Puerto Rico results page
# 50                 Go to page United States Virgin Islands result...
# 51           100%                          Biden 33.1% 287,021 votes
# 52           100%                          Biden 50.1% 703,486 votes
# 53           100%                          Biden 66.1% 242,820 votes
# 54           100%                          Biden 39.9% 856,034 votes
# 55           100%                          Biden 59.4% 307,486 votes
#
#                                                   URL
# 0   /politics/2020-elections/alabama-president-res...
# 1   /politics/2020-elections/alaska-president-resu...
# 2   /politics/2020-elections/arizona-president-res...
# 3   /politics/2020-elections/colorado-president-re...
# 4   /politics/2020-elections/florida-president-res...
# 5   /politics/2020-elections/georgia-president-res...
# 6   /politics/2020-elections/indiana-president-res...
# 7   /politics/2020-elections/kansas-president-resu...
# 8   /politics/2020-elections/maine-president-resul...
# 9   /politics/2020-elections/massachusetts-preside...
# 10  /politics/2020-elections/minnesota-president-r...
# 11  /politics/2020-elections/new-jersey-president-...
# 12  /politics/2020-elections/north-carolina-presid...
# 13  /politics/2020-elections/north-dakota-presiden...
# 14  /politics/2020-elections/oklahoma-president-re...
# 15  /politics/2020-elections/pennsylvania-presiden...
# 16  /politics/2020-elections/south-dakota-presiden...
# 17  /politics/2020-elections/texas-president-resul...
# 18  /politics/2020-elections/wyoming-president-res...
# 19  /politics/2020-elections/connecticut-president...
# 20  /politics/2020-elections/missouri-president-re...
# 21  /politics/2020-elections/west-virginia-preside...
# 22  /politics/2020-elections/illinois-president-re...
# 23  /politics/2020-elections/new-mexico-president-...
# 24  /politics/2020-elections/arkansas-president-re...
# 25  /politics/2020-elections/california-president-...
# 26  /politics/2020-elections/delaware-president-re...
# 27  /politics/2020-elections/district-of-columbia-...
# 28  /politics/2020-elections/hawaii-president-resu...
# 29  /politics/2020-elections/iowa-president-result...
# 30  /politics/2020-elections/kentucky-president-re...
# 31  /politics/2020-elections/maryland-president-re...
# 32  /politics/2020-elections/michigan-president-re...
# 33  /politics/2020-elections/mississippi-president...
# 34  /politics/2020-elections/montana-president-res...
# 35  /politics/2020-elections/new-hampshire-preside...
# 36  /politics/2020-elections/new-york-president-re...
# 37  /politics/2020-elections/ohio-president-result...
# 38  /politics/2020-elections/oregon-president-resu...
# 39  /politics/2020-elections/tennessee-president-r...
# 40  /politics/2020-elections/utah-president-result...
# 41  /politics/2020-elections/virginia-president-re...
# 42  /politics/2020-elections/washington-president-...
# 43  /politics/2020-elections/wisconsin-president-r...
# 44                      undefined?icid=election_usmap
# 45                      undefined?icid=election_usmap
# 46                      undefined?icid=election_usmap
# 47  /politics/2020-elections/nebraska-president-re...
# 48  /politics/2020-elections/south-carolina-presid...
# 49                      undefined?icid=election_usmap
# 50                      undefined?icid=election_usmap
# 51  /politics/2020-elections/idaho-president-resul...
# 52  /politics/2020-elections/nevada-president-resu...
# 53  /politics/2020-elections/vermont-president-res...
# 54  /politics/2020-elections/louisiana-president-r...
# 55  /politics/2020-elections/rhode-island-presiden...

# %%
results_2020 = results_2020.drop(index = [44,45,46,49,50])
len(results_2020)
# Out:
# 51

# %%
results_2020['Trump Results'] = trump

# %% [markdown]
# ### Part 3: Cleaning the DataFrame
#
# Although the data had already come a long way from the HTML format, there was more to do before it would be usable as a CSV.
#
# The first step I took was removing the '% Vote Counted' column - at the time of scraping this data, all states and territories had either 99% or 100% of votes counted, making this measure unimportant.
#
# The next step was separating the results for each candidate into distinct columns for vote count and percentage. I ran into a problem, however, when attempting this: I was getting an error. After looking at the results of the column split in a new list, I realized that the data for the US territories was empty, so I removed these from my dataframe. This left only the fifty states and Washington D.C. as my row values.

# %%
results_2020['% Vote Counted'].value_counts()
# Out:
# 100%    48
# 99%      3
# Name: % Vote Counted, dtype: int64

# %%
results_2020 = results_2020.drop(columns = '% Vote Counted')
results_2020.head()
# Out:
#       State Electoral Votes                Biden Results  \
# 0   Alabama               9    Biden 36.6% 849,648 votes
# 1    Alaska               3    Biden 42.8% 153,778 votes
# 2   Arizona              11  Biden 49.4% 1,672,143 votes
# 3  Colorado               9  Biden 55.4% 1,804,352 votes
# 4   Florida              29  Biden 47.9% 5,297,045 votes
#
#                                                  URL  \
# 0  /politics/2020-elections/alabama-president-res...
# 1  /politics/2020-elections/alaska-president-resu...
# 2  /politics/2020-elections/arizona-president-res...
# 3  /politics/2020-elections/colorado-president-re...
# 4  /politics/2020-elections/florida-president-res...
#
#                  Trump Results
# 0    Trump 62% 1,441,168 votes
# 1    Trump 52.8% 189,951 votes
# 2  Trump 49.1% 1,661,686 votes
# 3  Trump 41.9% 1,364,607 votes
# 4  Trump 51.2% 5,668,731 votes

# %% [markdown]
# #### 3.1: Splitting Columns
#
# After cleaning the territories from my data, I was able to successfully split the data for each candidate's votes into three distinct columns. I then removed the original columns from the dataframe, as well as the ones which just contained the values 'Biden' or 'Trump'.
#
# Then, I cleaned the URL column. Because of the way that the data was stored in the HTML file, the base URL https://www.nbcnews.com/ was missing, so I concatenated it with the values in the URL column.

# %%
results_2020[['Biden','Biden Vote Share','Biden Vote Count']]= results_2020['Biden Results'].str.split(" ",n=2,expand = True)
results_2020[['Trump','Trump Vote Share','Trump Vote Count']]= results_2020['Trump Results'].str.split(" ",n=2,expand = True)
results_2020 = results_2020.drop(columns = ['Trump','Biden','Trump Results','Biden Results'])
results_2020['URL']='https://www.nbcnews.com'+results_2020['URL']
results_2020.head()
# Out:
#       State Electoral Votes  \
# 0   Alabama               9
# 1    Alaska               3
# 2   Arizona              11
# 3  Colorado               9
# 4   Florida              29
#
#                                                  URL Biden Vote Share  \
# 0  https://www.nbcnews.com/politics/2020-election...            36.6%
# 1  https://www.nbcnews.com/politics/2020-election...            42.8%
# 2  https://www.nbcnews.com/politics/2020-election...            49.4%
# 3  https://www.nbcnews.com/politics/2020-election...            55.4%
# 4  https://www.nbcnews.com/politics/2020-election...            47.9%
#
#   Biden Vote Count Trump Vote Share Trump Vote Count
# 0    849,648 votes              62%  1,441,168 votes
# 1    153,778 votes            52.8%    189,951 votes
# 2  1,672,143 votes            49.1%  1,661,686 votes
# 3  1,804,352 votes            41.9%  1,364,607 votes
# 4  5,297,045 votes            51.2%  5,668,731 votes

# %% [markdown]
# #### 3.2: Cleaning Numeric Data
#
# All of the columns at this point are 'object' dtype, but most of them hold numeric values.
#
# First, I cleaned the percentage data by eliminating the percent sign, converting each datapoint to a float data type, and dividing the number by 100 to get the raw ratio.
#
# I used a similar function on the vote count columns. Here, I eliminated the word 'votes' and got rid of the commas. I then converted the data to dtype integer.
#
# Finally, I converted the 'Electoral Votes' Column to dtype integer as well.

# %%
percent_cols = ['Biden Vote Share','Trump Vote Share']
def clean_percent(item): 
    item = item.replace('%',"")
    item = float(item)
    item = item/100 
    return item
for col in percent_cols: 
    results_2020[col] = results_2020[col].apply(clean_percent)
results_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 55
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             51 non-null     object
#  1   Electoral Votes   51 non-null     object
#  2   URL               51 non-null     object
#  3   Biden Vote Share  51 non-null     float64
#  4   Biden Vote Count  51 non-null     object
#  5   Trump Vote Share  51 non-null     float64
#  6   Trump Vote Count  51 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 3.2+ KB

# %%
count_cols = ['Biden Vote Count', 'Trump Vote Count']
def clean_count(item):
    item = item.replace(' votes',"")
    item = item.replace(',',"")
    item = int(item)
    return item
for col in count_cols: 
    results_2020[col] = results_2020[col].apply(clean_count)
results_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 55
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             51 non-null     object
#  1   Electoral Votes   51 non-null     object
#  2   URL               51 non-null     object
#  3   Biden Vote Share  51 non-null     float64
#  4   Biden Vote Count  51 non-null     int64
#  5   Trump Vote Share  51 non-null     float64
#  6   Trump Vote Count  51 non-null     int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 3.2+ KB

# %%
results_2020['Electoral Votes'] = results_2020['Electoral Votes'].astype(int)
results_2020.head()
# Out:
#       State  Electoral Votes  \
# 0   Alabama                9
# 1    Alaska                3
# 2   Arizona               11
# 3  Colorado                9
# 4   Florida               29
#
#                                                  URL  Biden Vote Share  \
# 0  https://www.nbcnews.com/politics/2020-election...             0.366
# 1  https://www.nbcnews.com/politics/2020-election...             0.428
# 2  https://www.nbcnews.com/politics/2020-election...             0.494
# 3  https://www.nbcnews.com/politics/2020-election...             0.554
# 4  https://www.nbcnews.com/politics/2020-election...             0.479
#
#    Biden Vote Count  Trump Vote Share  Trump Vote Count
# 0            849648             0.620           1441168
# 1            153778             0.528            189951
# 2           1672143             0.491           1661686
# 3           1804352             0.419           1364607
# 4           5297045             0.512           5668731

# %% [markdown]
# #### 3.3: Sorting Data
#
# The data is really close to being ready to export, but I realized that the states are in a random order. I sorted the data alphabetically by state, the format in which one would expect this data to be displayed.

# %%
results_2020 = results_2020.sort_values(by='State')
results_2020.reset_index(drop=True,inplace = True,)
results_2020.head()
# Out:
#         State  Electoral Votes  \
# 0     Alabama                9
# 1      Alaska                3
# 2     Arizona               11
# 3    Arkansas                6
# 4  California               55
#
#                                                  URL  Biden Vote Share  \
# 0  https://www.nbcnews.com/politics/2020-election...             0.366
# 1  https://www.nbcnews.com/politics/2020-election...             0.428
# 2  https://www.nbcnews.com/politics/2020-election...             0.494
# 3  https://www.nbcnews.com/politics/2020-election...             0.348
# 4  https://www.nbcnews.com/politics/2020-election...             0.635
#
#    Biden Vote Count  Trump Vote Share  Trump Vote Count
# 0            849648             0.620           1441168
# 1            153778             0.528            189951
# 2           1672143             0.491           1661686
# 3            423932             0.624            760647
# 4          11109764             0.343           6005961

# %% [markdown]
# ### Step 4: Exporting the Data
#
# Now that I am happy with how my data looks, I can export my data to a CSV file.
# I simply used the pandas.to_csv( ) function for this.

# %%
results_2020.to_csv('/Users/austenbrockman/Desktop/python/NBC 2020 Election Results.csv', index=False)
